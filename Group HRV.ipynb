# %%
import pandas as pd
import numpy as np

# Function to calculate HRV metrics
def calculate_hrv_std(ibi_data):
    valid_ibi = pd.Series(ibi_data)
    sdnn = np.std(valid_ibi, ddof=1)
    return sdnn

# Load datasets for all participants
participants_data = {
    'P01': [pd.read_csv('/Users/urmebose/Desktop/Style/P01/Nuro/ibi_01.csv'),
            pd.read_csv('/Users/urmebose/Desktop/Style/P01/Nuro/ibi_02.csv'),
            pd.read_csv('/Users/urmebose/Desktop/Style/P01/Nuro/ibi_03.csv')],
    'P02': [pd.read_csv('/Users/urmebose/Desktop/Style/P02/Nuro/ibi_01.csv'),
            pd.read_csv('/Users/urmebose/Desktop/Style/P02/Nuro/ibi_02.csv'),
            pd.read_csv('/Users/urmebose/Desktop/Style/P02/Nuro/ibi_03.csv')],
    'P03': [pd.read_csv('/Users/urmebose/Desktop/Style/P03/Nuro/ibi_01.csv'),
            pd.read_csv('/Users/urmebose/Desktop/Style/P03/Nuro/ibi_02.csv'),
            pd.read_csv('/Users/urmebose/Desktop/Style/P03/Nuro/ibi_03.csv')],
    'P04': [pd.read_csv('/Users/urmebose/Desktop/Style/P04/Nuro/ibi_01.csv'),
            pd.read_csv('/Users/urmebose/Desktop/Style/P04/Nuro/ibi_02.csv'),
            pd.read_csv('/Users/urmebose/Desktop/Style/P04/Nuro/ibi_03.csv')],
    'P05': [pd.read_csv('/Users/urmebose/Desktop/Style/P05/Nuro/ibi_01.csv'),
            pd.read_csv('/Users/urmebose/Desktop/Style/P05/Nuro/ibi_02.csv'),
            pd.read_csv('/Users/urmebose/Desktop/Style/P05/Nuro/ibi_03.csv')],
    'P06': [pd.read_csv('/Users/urmebose/Desktop/Style/P06/Nuro/ibi_01.csv'),
            pd.read_csv('/Users/urmebose/Desktop/Style/P06/Nuro/ibi_02.csv'),
            pd.read_csv('/Users/urmebose/Desktop/Style/P06/Nuro/ibi_03.csv')],
    'P07': [pd.read_csv('/Users/urmebose/Desktop/Style/P07/Nuro/ibi_01.csv'),
            pd.read_csv('/Users/urmebose/Desktop/Style/P07/Nuro/ibi_02.csv'),
            pd.read_csv('/Users/urmebose/Desktop/Style/P07/Nuro/ibi_03.csv')],
    'P08': [pd.read_csv('/Users/urmebose/Desktop/Style/P08/Nuro/ibi_01.csv'),
            pd.read_csv('/Users/urmebose/Desktop/Style/P08/Nuro/ibi_02.csv'),
            pd.read_csv('/Users/urmebose/Desktop/Style/P08/Nuro/ibi_03.csv')],
    'P09': [pd.read_csv('/Users/urmebose/Desktop/Style/P09/Nuro/ibi_01.csv'),
            pd.read_csv('/Users/urmebose/Desktop/Style/P09/Nuro/ibi_02.csv'),
            pd.read_csv('/Users/urmebose/Desktop/Style/P09/Nuro/ibi_03.csv')],
    'P10': [pd.read_csv('/Users/urmebose/Desktop/Style/P10/Nuro/ibi_01.csv'),
            pd.read_csv('/Users/urmebose/Desktop/Style/P10/Nuro/ibi_02.csv'),
            pd.read_csv('/Users/urmebose/Desktop/Style/P10/Nuro/ibi_03.csv')]
}

# Initialize a list to collect the SDNN results
results = []

# Process data for each participant
for participant_id, data in participants_data.items():
    participant_results = {'Participant': participant_id}
    for session_number, df in enumerate(data, start=1):
        std_dev = calculate_hrv_std(df['ibi'])
        participant_results[f'Session {session_number:02d}'] = std_dev
        # Debug print for verification
        print(f"{participant_id}, Session {session_number}, SDNN: {std_dev:.2f} ms")
    results.append(participant_results)

# Convert results to DataFrame
results_df = pd.DataFrame(results)

# Display the results
print(results_df)

# Save the results to a CSV file
results_df.to_csv('/Users/urmebose/Desktop/Style/HRV_SDNN_Results.csv', index=False)
# Out:
# P01, Session 1, SDNN: 80.14 ms
# P01, Session 2, SDNN: 65.39 ms
# P01, Session 3, SDNN: 1012.69 ms
# P02, Session 1, SDNN: 46.20 ms
# P02, Session 2, SDNN: 47.81 ms
# P02, Session 3, SDNN: 47.40 ms
# P03, Session 1, SDNN: 54.98 ms
# P03, Session 2, SDNN: 56.83 ms
# P03, Session 3, SDNN: 39.02 ms
# P04, Session 1, SDNN: 41.38 ms
# P04, Session 2, SDNN: 39.89 ms
# P04, Session 3, SDNN: 55.02 ms
# P05, Session 1, SDNN: 34.73 ms
# P05, Session 2, SDNN: 32.62 ms
# P05, Session 3, SDNN: 37.63 ms
# P06, Session 1, SDNN: 41.64 ms
# P06, Session 2, SDNN: 122.35 ms
# P06, Session 3, SDNN: 117.05 ms
# P07, Session 1, SDNN: 42.21 ms
# P07, Session 2, SDNN: 59.67 ms
# P07, Session 3, SDNN: 50.04 ms
# P08, Session 1, SDNN: 188.91 ms
# P08, Session 2, SDNN: 56.44 ms
# P08, Session 3, SDNN: 58.87 ms
# P09, Session 1, SDNN: 38.50 ms
# P09, Session 2, SDNN: 41.89 ms
# P09, Session 3, SDNN: 47.27 ms
# P10, Session 1, SDNN: 43.43 ms
# P10, Session 2, SDNN: 50.13 ms
# P10, Session 3, SDNN: 55.75 ms
#   Participant  Session 01  Session 02   Session 03
# 0         P01   80.143972   65.393810  1012.692348
# 1         P02   46.196011   47.808084    47.399234
# 2         P03   54.978636   56.826452    39.020069
# 3         P04   41.381410   39.887830    55.024293
# 4         P05   34.731159   32.623213    37.633168
# 5         P06   41.640502  122.352487   117.053313
# 6         P07   42.205171   59.674890    50.044795
# 7         P08  188.911753   56.440384    58.873614
# 8         P09   38.500288   41.885991    47.267463
# 9         P10   43.433112   50.125105    55.747270

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Function to calculate HRV metrics
def calculate_hrv_std(ibi_data):
    valid_ibi = pd.Series(ibi_data)
    sdnn = np.std(valid_ibi, ddof=1)
    return sdnn

# Load datasets for all participants
participants_data = {
    'P01': [pd.read_csv('/Users/urmebose/Desktop/Style/P01/Nuro/ibi_01.csv'),
            pd.read_csv('/Users/urmebose/Desktop/Style/P01/Nuro/ibi_02.csv'),
            pd.read_csv('/Users/urmebose/Desktop/Style/P01/Nuro/ibi_03.csv')],
    'P02': [pd.read_csv('/Users/urmebose/Desktop/Style/P02/Nuro/ibi_01.csv'),
            pd.read_csv('/Users/urmebose/Desktop/Style/P02/Nuro/ibi_02.csv'),
            pd.read_csv('/Users/urmebose/Desktop/Style/P02/Nuro/ibi_03.csv')],
    'P03': [pd.read_csv('/Users/urmebose/Desktop/Style/P03/Nuro/ibi_01.csv'),
            pd.read_csv('/Users/urmebose/Desktop/Style/P03/Nuro/ibi_02.csv'),
            pd.read_csv('/Users/urmebose/Desktop/Style/P03/Nuro/ibi_03.csv')],
    'P04': [pd.read_csv('/Users/urmebose/Desktop/Style/P04/Nuro/ibi_01.csv'),
            pd.read_csv('/Users/urmebose/Desktop/Style/P04/Nuro/ibi_02.csv'),
            pd.read_csv('/Users/urmebose/Desktop/Style/P04/Nuro/ibi_03.csv')],
    'P05': [pd.read_csv('/Users/urmebose/Desktop/Style/P05/Nuro/ibi_01.csv'),
            pd.read_csv('/Users/urmebose/Desktop/Style/P05/Nuro/ibi_02.csv'),
            pd.read_csv('/Users/urmebose/Desktop/Style/P05/Nuro/ibi_03.csv')],
    'P06': [pd.read_csv('/Users/urmebose/Desktop/Style/P06/Nuro/ibi_01.csv'),
            pd.read_csv('/Users/urmebose/Desktop/Style/P06/Nuro/ibi_02.csv'),
            pd.read_csv('/Users/urmebose/Desktop/Style/P06/Nuro/ibi_03.csv')],
    'P07': [pd.read_csv('/Users/urmebose/Desktop/Style/P07/Nuro/ibi_01.csv'),
            pd.read_csv('/Users/urmebose/Desktop/Style/P07/Nuro/ibi_02.csv'),
            pd.read_csv('/Users/urmebose/Desktop/Style/P07/Nuro/ibi_03.csv')],
    'P08': [pd.read_csv('/Users/urmebose/Desktop/Style/P08/Nuro/ibi_01.csv'),
            pd.read_csv('/Users/urmebose/Desktop/Style/P08/Nuro/ibi_02.csv'),
            pd.read_csv('/Users/urmebose/Desktop/Style/P08/Nuro/ibi_03.csv')],
    'P09': [pd.read_csv('/Users/urmebose/Desktop/Style/P09/Nuro/ibi_01.csv'),
            pd.read_csv('/Users/urmebose/Desktop/Style/P09/Nuro/ibi_02.csv'),
            pd.read_csv('/Users/urmebose/Desktop/Style/P09/Nuro/ibi_03.csv')],
    'P10': [pd.read_csv('/Users/urmebose/Desktop/Style/P10/Nuro/ibi_01.csv'),
            pd.read_csv('/Users/urmebose/Desktop/Style/P10/Nuro/ibi_02.csv'),
            pd.read_csv('/Users/urmebose/Desktop/Style/P10/Nuro/ibi_03.csv')]
}

# Initialize a list to collect the SDNN results
results = []

# Process data for each participant
for participant_id, data in participants_data.items():
    participant_results = {'Participant': participant_id}
    for session_number, df in enumerate(data, start=1):
        std_dev = calculate_hrv_std(df['ibi'])
        participant_results[f'Session {session_number:02d}'] = std_dev
        # Debug print for verification
        print(f"{participant_id}, Session {session_number}, SDNN: {std_dev:.2f} ms")
    results.append(participant_results)

# Convert results to DataFrame
results_df = pd.DataFrame(results)

# Display the results
print(results_df)

# Save the results to a CSV file
results_df.to_csv('/Users/urmebose/Desktop/HRV_SDNN_Results.csv', index=False)

# Plot the standard deviations of HRV (SDNN) for each participant across three sessions
results_df.set_index('Participant', inplace=True)
results_df.T.plot(figsize=(15, 8), marker='o')

plt.title('Standard Deviation of HRV (SDNN) for Each Participant Across Three Sessions')
plt.ylabel('Standard Deviation of HRV (SDNN) (ms)')
plt.xlabel('Session')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Add reference lines for normal, moderate, and high durations
plt.axhline(y=50, color='blue', linestyle=':', label='Normal')
plt.axhline(y=100, color='purple', linestyle=':', label='Moderate Duration')
plt.axhline(y=150, color='green', linestyle=':', label='High Duration')

plt.legend(title='HRV Levels')
plt.show()
# Out:
# P01, Session 1, SDNN: 80.14 ms
# P01, Session 2, SDNN: 65.39 ms
# P01, Session 3, SDNN: 1012.69 ms
# P02, Session 1, SDNN: 46.20 ms
# P02, Session 2, SDNN: 47.81 ms
# P02, Session 3, SDNN: 47.40 ms
# P03, Session 1, SDNN: 54.98 ms
# P03, Session 2, SDNN: 56.83 ms
# P03, Session 3, SDNN: 39.02 ms
# P04, Session 1, SDNN: 41.38 ms
# P04, Session 2, SDNN: 39.89 ms
# P04, Session 3, SDNN: 55.02 ms
# P05, Session 1, SDNN: 34.73 ms
# P05, Session 2, SDNN: 32.62 ms
# P05, Session 3, SDNN: 37.63 ms
# P06, Session 1, SDNN: 41.64 ms
# P06, Session 2, SDNN: 122.35 ms
# P06, Session 3, SDNN: 117.05 ms
# P07, Session 1, SDNN: 42.21 ms
# P07, Session 2, SDNN: 59.67 ms
# P07, Session 3, SDNN: 50.04 ms
# P08, Session 1, SDNN: 188.91 ms
# P08, Session 2, SDNN: 56.44 ms
# P08, Session 3, SDNN: 58.87 ms
# P09, Session 1, SDNN: 38.50 ms
# P09, Session 2, SDNN: 41.89 ms
# P09, Session 3, SDNN: 47.27 ms
# P10, Session 1, SDNN: 43.43 ms
# P10, Session 2, SDNN: 50.13 ms
# P10, Session 3, SDNN: 55.75 ms
#   Participant  Session 01  Session 02   Session 03
# 0         P01   80.143972   65.393810  1012.692348
# 1         P02   46.196011   47.808084    47.399234
# 2         P03   54.978636   56.826452    39.020069
# 3         P04   41.381410   39.887830    55.024293
# 4         P05   34.731159   32.623213    37.633168
# 5         P06   41.640502  122.352487   117.053313
# 6         P07   42.205171   59.674890    50.044795
# 7         P08  188.911753   56.440384    58.873614
# 8         P09   38.500288   41.885991    47.267463
# 9         P10   43.433112   50.125105    55.747270

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Function to calculate HRV metrics
def calculate_hrv_std(ibi_data):
    valid_ibi = pd.Series(ibi_data)
    sdnn = np.std(valid_ibi, ddof=1)
    return sdnn

# Load datasets for all participants
participants_data = {
    'P01': [pd.read_csv('/Users/urmebose/Desktop/Style/P01/Nuro/ibi_01.csv'),
            pd.read_csv('/Users/urmebose/Desktop/Style/P01/Nuro/ibi_02.csv'),
            pd.read_csv('/Users/urmebose/Desktop/Style/P01/Nuro/ibi_03.csv')],
    'P02': [pd.read_csv('/Users/urmebose/Desktop/Style/P02/Nuro/ibi_01.csv'),
            pd.read_csv('/Users/urmebose/Desktop/Style/P02/Nuro/ibi_02.csv'),
            pd.read_csv('/Users/urmebose/Desktop/Style/P02/Nuro/ibi_03.csv')],
    'P03': [pd.read_csv('/Users/urmebose/Desktop/Style/P03/Nuro/ibi_01.csv'),
            pd.read_csv('/Users/urmebose/Desktop/Style/P03/Nuro/ibi_02.csv'),
            pd.read_csv('/Users/urmebose/Desktop/Style/P03/Nuro/ibi_03.csv')],
    'P04': [pd.read_csv('/Users/urmebose/Desktop/Style/P04/Nuro/ibi_01.csv'),
            pd.read_csv('/Users/urmebose/Desktop/Style/P04/Nuro/ibi_02.csv'),
            pd.read_csv('/Users/urmebose/Desktop/Style/P04/Nuro/ibi_03.csv')],
    'P05': [pd.read_csv('/Users/urmebose/Desktop/Style/P05/Nuro/ibi_01.csv'),
            pd.read_csv('/Users/urmebose/Desktop/Style/P05/Nuro/ibi_02.csv'),
            pd.read_csv('/Users/urmebose/Desktop/Style/P05/Nuro/ibi_03.csv')],
    'P06': [pd.read_csv('/Users/urmebose/Desktop/Style/P06/Nuro/ibi_01.csv'),
            pd.read_csv('/Users/urmebose/Desktop/Style/P06/Nuro/ibi_02.csv'),
            pd.read_csv('/Users/urmebose/Desktop/Style/P06/Nuro/ibi_03.csv')],
    'P07': [pd.read_csv('/Users/urmebose/Desktop/Style/P07/Nuro/ibi_01.csv'),
            pd.read_csv('/Users/urmebose/Desktop/Style/P07/Nuro/ibi_02.csv'),
            pd.read_csv('/Users/urmebose/Desktop/Style/P07/Nuro/ibi_03.csv')],
    'P08': [pd.read_csv('/Users/urmebose/Desktop/Style/P08/Nuro/ibi_01.csv'),
            pd.read_csv('/Users/urmebose/Desktop/Style/P08/Nuro/ibi_02.csv'),
            pd.read_csv('/Users/urmebose/Desktop/Style/P08/Nuro/ibi_03.csv')],
    'P09': [pd.read_csv('/Users/urmebose/Desktop/Style/P09/Nuro/ibi_01.csv'),
            pd.read_csv('/Users/urmebose/Desktop/Style/P09/Nuro/ibi_02.csv'),
            pd.read_csv('/Users/urmebose/Desktop/Style/P09/Nuro/ibi_03.csv')],
    'P10': [pd.read_csv('/Users/urmebose/Desktop/Style/P10/Nuro/ibi_01.csv'),
            pd.read_csv('/Users/urmebose/Desktop/Style/P10/Nuro/ibi_02.csv'),
            pd.read_csv('/Users/urmebose/Desktop/Style/P10/Nuro/ibi_03.csv')]
}

# Initialize a list to collect the SDNN results
results = []

# Process data for each participant
for participant_id, data in participants_data.items():
    participant_results = {'Participant': participant_id}
    for session_number, df in enumerate(data, start=1):
        std_dev = calculate_hrv_std(df['ibi'])
        participant_results[f'Session {session_number:02d}'] = std_dev
        # Debug print for verification
        print(f"{participant_id}, Session {session_number}, SDNN: {std_dev:.2f} ms")
    results.append(participant_results)

# Convert results to DataFrame
results_df = pd.DataFrame(results)

# Display the results
print(results_df)

# Save the results to a CSV file
results_df.to_csv('/Users/urmebose/Desktop/Style/HRV_SDNN_Results.csv', index=False)

# Plot the standard deviations of HRV (SDNN) for each participant across three sessions
results_df.set_index('Participant', inplace=True)
results_df.plot(figsize=(15, 8), marker='o')

plt.title('Standard Deviation of HRV (SDNN) for Each Participant Across Three Sessions')
plt.ylabel('Standard Deviation of HRV (SDNN) (ms)')
plt.xlabel('Participant')
plt.xticks(ticks=np.arange(len(results_df.index)), labels=results_df.index, rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Add reference lines for normal, moderate, and high durations
plt.axhline(y=50, color='blue', linestyle=':', label='Normal')
plt.axhline(y=100, color='purple', linestyle=':', label='Moderate Duration')
plt.axhline(y=150, color='green', linestyle=':', label='High Duration')

plt.legend(title='HRV Levels')
plt.show()
# Out:
# P01, Session 1, SDNN: 80.14 ms
# P01, Session 2, SDNN: 65.39 ms
# P01, Session 3, SDNN: 1012.69 ms
# P02, Session 1, SDNN: 46.20 ms
# P02, Session 2, SDNN: 47.81 ms
# P02, Session 3, SDNN: 47.40 ms
# P03, Session 1, SDNN: 54.98 ms
# P03, Session 2, SDNN: 56.83 ms
# P03, Session 3, SDNN: 39.02 ms
# P04, Session 1, SDNN: 41.38 ms
# P04, Session 2, SDNN: 39.89 ms
# P04, Session 3, SDNN: 55.02 ms
# P05, Session 1, SDNN: 34.73 ms
# P05, Session 2, SDNN: 32.62 ms
# P05, Session 3, SDNN: 37.63 ms
# P06, Session 1, SDNN: 41.64 ms
# P06, Session 2, SDNN: 122.35 ms
# P06, Session 3, SDNN: 117.05 ms
# P07, Session 1, SDNN: 42.21 ms
# P07, Session 2, SDNN: 59.67 ms
# P07, Session 3, SDNN: 50.04 ms
# P08, Session 1, SDNN: 188.91 ms
# P08, Session 2, SDNN: 56.44 ms
# P08, Session 3, SDNN: 58.87 ms
# P09, Session 1, SDNN: 38.50 ms
# P09, Session 2, SDNN: 41.89 ms
# P09, Session 3, SDNN: 47.27 ms
# P10, Session 1, SDNN: 43.43 ms
# P10, Session 2, SDNN: 50.13 ms
# P10, Session 3, SDNN: 55.75 ms
#   Participant  Session 01  Session 02   Session 03
# 0         P01   80.143972   65.393810  1012.692348
# 1         P02   46.196011   47.808084    47.399234
# 2         P03   54.978636   56.826452    39.020069
# 3         P04   41.381410   39.887830    55.024293
# 4         P05   34.731159   32.623213    37.633168
# 5         P06   41.640502  122.352487   117.053313
# 6         P07   42.205171   59.674890    50.044795
# 7         P08  188.911753   56.440384    58.873614
# 8         P09   38.500288   41.885991    47.267463
# 9         P10   43.433112   50.125105    55.747270
